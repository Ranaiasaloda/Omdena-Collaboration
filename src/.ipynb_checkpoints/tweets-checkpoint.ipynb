# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\96278\Omdena-Project-rana\data\healthcare_tweets.csv')
sentiment_counts = df['sentiment'].value_counts()


sentiment_counts_df = sentiment_counts.reset_index()
sentiment_counts_df.columns = ['Sentiment', 'Count']


display(sentiment_counts_df)
# Out:
#   Sentiment  Count
# 0  negative      2
# 1  positive      2
# 2   neutral      1

# %%
    plt.figure(figsize=(6,4))
    plt.bar(sentiment_counts_df['Sentiment'], sentiment_counts_df['Count'], color=['green','red','blue'])
    plt.title("Tweet Sentiments - Matplotlib")
    plt.xlabel("Sentiment")
    plt.ylabel("Number of Tweets")
    plt.savefig('plots/sentiment_bar.png')
    plt.close()     # يغلق الرسم الحالي لتجنب تراكب الرسومات
